# %%
import cups

# %%
cups_connection = cups.Connection()
file_path = "/resources/images/6fa65f044c9240e5a728e2f6cc67b10a-qr.jpg"
job_id = cups_connection.printFile(
    "EPSON_TM-T20IIIL",
    file_path,
    "Test Print",
    {},
)

job_id
