# %%
from por.utils.printer import get_printer

# %%
printer = get_printer()
printer.image(img_source="/resources/ticket-images/por-logo.jpeg")
printer.text("\n\n")

# printer.set(bold=True)
printer.block_text("* Edicion Especial Yoizen")
# printer.set(bold=False)
printer.text("\n\n")

printer.image(img_source="/resources/ticket-images/yzn-logo.jpeg")
# printer.text("\n\n")

# printer.text("\n\n")
# printer.set(font=0, double_width=False, double_height=False)
# printer.set(align="left")
# # printer.block_text("* Made in Iturri")
# # printer.text("\n")
# printer.block_text("* x el Oráculo Robot. (2025, ∞)")

printer.cut()
printer.close()
