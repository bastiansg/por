# %%
from common.utils.json_data import load_json

from por.multi_agent.schema import StateSchema
from por.multi_agent.nodes.printer import print_pipeline

# %%
printer_config = {
    "por_logo_path": "/resources/ticket-images/por-logo.jpeg",
    "max_text_len": 48,
}

state = load_json("/resources/states/b4e127b95883419087eb1c878747a585.json")
state = StateSchema(**state)
