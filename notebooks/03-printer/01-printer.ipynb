# %%
import cups

from rich.pretty import pprint

# %%
conn = cups.Connection()
printers = conn.getPrinters()

printers

# %%
file_path = "/resources/images/qr-test.jpg"
job_id = conn.printFile("EPSON_TM-T20IIIL", file_path, "Test Print", {})
