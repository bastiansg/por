# %%
import json

from rich.pretty import pprint

from por.multi_agent.schema import StateSchema
from por.multi_agent.nodes.utils import get_printer
from por.multi_agent.nodes.printer import main_pipeline

# %%
def load_json(file_path: str) -> dict:
    with open(file_path, "r") as f:
        return json.loads(f.read())

# %%
state_path = "/resources/states/01046ab19a59408e8167a9bc01649a75.json"
state = StateSchema(**load_json(state_path))  # type: ignore
pprint(state)

# %%
printer = get_printer()
main_pipeline(
    printer=printer,
    por_logo_path="/resources/ticket-images/por-logo.jpeg",
    state=state,
)
