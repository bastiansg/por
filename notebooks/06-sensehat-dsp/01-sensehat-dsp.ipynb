# %%
from time import sleep
from sensehat_dsp.display import Display

# %%
display = Display()

# %%
# image_name = "space-invader-1b"
image_name = "space-invader-2"
# image_name = "space-invader-5a"

display.set_image(image_name=image_name)
sleep(3)
display.clear()
