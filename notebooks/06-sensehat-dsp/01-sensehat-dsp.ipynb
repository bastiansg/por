# %%
from time import sleep

from rich.pretty import pprint
from por.multi_agent.nodes.utils import get_dsp_images, get_sensehat_dsp

# %%
dsp_images = get_dsp_images()
sensehat_dsp = get_sensehat_dsp()

# %%
pprint([img.name for img in dsp_images.values()])

# %%
# sensehat_dsp.start_image_sequence(
#     images=[
#         dsp_images["08a"],
#         dsp_images["08b"],
#     ],
#     refresh_rate=3.0,
# )

# sensehat_dsp.set_image(image=dsp_images["08a"])
sensehat_dsp.start_color_cycle(image=dsp_images["chess-board"])

# %%
sensehat_dsp.stop()
sensehat_dsp.clear()
