# %%
import logfire

from rich.pretty import pprint
from por.spotify import Spotify

# %%
logfire.configure(service_name="por")
_ = logfire.instrument_pydantic_ai()

# %%
spotify = Spotify()

# %%
artist = await spotify.serch_artist("The Rolling Stones")
pprint(artist)

assert artist is not None
albums = spotify.get_artist_albums(artist=artist)
pprint(albums)

# %%
# album_tracks = spotify.get_albums_tracks(albums=albums)
# print(len(album_tracks))

pprint(album_tracks[:10])

# %%
artists = {
    "AURORA",
    "Alexandra Savior",
    "Arcade Fire",
    "Babasonicos",
    "Backstreet Boys",
    "Björk",
    "Blonde Redhead",
    "Charly García",
    "Cranes",
    "David Bowie",
    "Depeche Mode",
    "Elvis Presley",
    "Gorillaz",
    "Gustavo Cerati",
    "John Maus",
    "MGMT",
    "Mac DeMarco",
    "Madonna",
    "Marika Hackman",
    "Massive Attack",
    "Metronomy",
    "Molly Nilsson",
    "PJ Harvey",
    "Pescado Rabioso",
    "Portishead",
    "Queen",
    "Radiohead",
    "Ramones",
    "Spice Girls",
    "Sumo",
    "Talking Heads",
    "Taylor Swift",
    "The Beatles",
    "The Clash",
    "The Cure",
    "The Doors",
    "The Dø",
    "The Growlers",
    "The Police",
    "The Rolling Stones",
    "The Smiths",
    "The Sound",
    "Virus",
    "Yeah Yeah Yeahs",
}
