# %%
from time import sleep

from rich.pretty import pprint

from por.dsp_images import dsp_images
from sensehat_dsp.display import Display, Image

# %%
display = Display()

# %%
images = {dsp_image["name"]: Image(**dsp_image) for dsp_image in dsp_images}
pprint(images.keys())

# %%
# display.set_image(image=images["si-02a"])

images_ = [
    # images["heart-01"],
    # images["heart-02"],
    # images["si-01a"],
    # images["si-01b"],
    # images["si-02a"],
    # images["si-02b"],
    # images["si-03b"],
    # images["si-03b"],
    images["si-04a"],
    images["si-04b"],
]

display.start_image_sequence(
    images=images_,
    refresh_rate=0.5,
)

sleep(3)

display.stop()
display.clear()

display.start_color_cycle(images["si-05"])
# display.start_color_cycle(images["down-arrow"])
# display.start_gol(
#     p_color=Color(
#         r=128,
#         g=128,
#         b=128,
#     ),
#     s_color=Color(
#         r=0,
#         g=0,
#         b=0,
#     ),
# )

# %%
display.stop()
display.clear()
