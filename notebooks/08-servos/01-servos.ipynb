# %%
from time import sleep
from hailo_apps.servos import Servos, ServoAngles

# %%
init_servo_angles = ServoAngles()
servos = Servos(init_servo_angles=init_servo_angles)

# %%
# servos.set_angles(servo_angles=ServoAngles(x=0, y=180))
# servos.set_angles(servo_angles=ServoAngles())

# %%
for i in range(180):
    servos.set_angles(servo_angles=ServoAngles(x=i, y=i))
    sleep(0.005)

servos.set_angles(servo_angles=init_servo_angles)
